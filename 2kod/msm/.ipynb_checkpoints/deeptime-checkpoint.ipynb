# %% [markdown]
# # Deeptime Notebook

# %% [markdown]
# A combination of the PyEMMA and Deeptime tutorials.
#
# For CA-CTD D1D2 standard simulation data.

# %%
# Imports
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import deeptime
import pickle
import wedap
from tqdm.auto import tqdm

# Require deeptime, ipywidgets, tqdm. numpy and matplotlib

# %%
# Common variables across all checkpoints
lagtimes = [1, 2, 5, 10, 20, 25]
n_clusters = [5, 10, 30, 75, 200, 450]

# %% [markdown]
# ### load features
# Eventually can just load this data in from the west.h5 file

# %%
# load in data, skip the first column of frame number
o_angles = np.loadtxt("o_angle.dat")[:,1:]
tt_dist = np.loadtxt("tt_dist.dat")[:,1:]

# column stack
features = np.hstack((o_angles, tt_dist))
features.shape
# Out:
# (680, 3)

# %%
dap = wedap.H5_Pdist("west-10k.h5", data_type="average")

# %%
oa1 = dap.get_total_data_array("o_angle_m1")
oa2 = dap.get_total_data_array("o_angle_m2")
tt = dap.get_total_data_array("tt_dist")
tt
# Out:
# Getting Data Array: 100%|█████████████████████████████████████████████| 10000/10000 [00:08<00:00, 1181.35it/s]
# Getting Data Array: 100%|█████████████████████████████████████████████| 10000/10000 [00:08<00:00, 1162.70it/s]
# Getting Data Array: 100%|█████████████████████████████████████████████| 10000/10000 [00:08<00:00, 1156.11it/s]
# array([[4.0292],
#        [8.1549],
#        [8.433 ],
#        ...,
#        [8.338 ],
#        [8.8768],
#        [9.0748]])

# %%
# column stack
features = np.hstack((oa1,oa2,tt))
features.shape
# Out:
# (7480000, 3)

# %% [markdown]
# ### cluster init

# %%
# Run K-means on multiple cluster numbers
clusters = []
dtrajs = []
for n in n_clusters:
    cluster = deeptime.clustering.KMeans(n_clusters=n, max_iter=500, progress=tqdm)
    dtraj = cluster.fit_transform(features)
    dtrajs.append(dtraj)
    clusters.append(cluster.fetch_model())
# Out:
# KMeans++ initialization: 100%|██████████████████████████████████████████████████| 5/5 [00:01<00:00,  4.86it/s]
# KMeans iterations:   3%|█▋                                                   | 16/500 [00:16<08:30,  1.05s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 6
#       4 for n in n_clusters:
#       5     cluster = deeptime.clustering.KMeans(n_clusters=n, max_iter=500, progress=tqdm)
# ----> 6     dtraj = cluster.fit_transform(features)
#       7     dtrajs.append(dtraj)
#       8     clusters.append(cluster.fetch_model())
#
# File ~/anaconda3/envs/msm/lib/python3.10/site-packages/deeptime/base.py:464, in EstimatorTransformer.fit_transform(self, data, fit_options, transform_options)
#     462 fit_options = {} if fit_options is None else fit_options
#     463 transform_options = {} if transform_options is None else transform_options
# --> 464 return self.fit(data, **fit_options).transform(data, **transform_options)
#
# File ~/anaconda3/envs/msm/lib/python3.10/site-packages/deeptime/base.py:417, in _ImmutableInputData.__call__(self, *args, **kwargs)
#     415 # here we invoke the immutable setting context manager.
#     416 with self:
# --> 417     return self.fit_method(*args, **kwargs)
#
# File ~/anaconda3/envs/msm/lib/python3.10/site-packages/deeptime/clustering/_kmeans.py:460, in KMeans.fit(self, data, initial_centers, callback_init_centers, callback_loop, n_jobs)
#     458     context = nullcontext()
#     459 with context:
# --> 460     cluster_centers, code, iterations, cost = impl.kmeans.cluster_loop(
#     461         data, self.initial_centers.copy(), n_jobs, self.max_iter,
#     462         self.tolerance, callback)
#     463 if code == 0:
#     464     converged = True
#
# File ~/anaconda3/envs/msm/lib/python3.10/site-packages/deeptime/clustering/_kmeans.py:567, in KMeansCallback.__call__(self, *args, **kw)
#     564     super().__init__(progress, description=description, total=total)
#     565     self._parent_callback = parent_callback
# --> 567 def __call__(self, *args, **kw):
#     568     super().__call__(*args, **kw)
#     569     if self._parent_callback is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Checkpoint 1/4

# %%
# Write previous data
import pickle
with open('clusters.pickle','wb') as file:
    pickle.dump(clusters, file)
with open('dtrajs.pickle','wb') as file:
    pickle.dump(dtrajs, file)

# %%
# Read previous data
import pickle
with open('clusters.pickle','rb') as file:
    clusters = pickle.load(file)
with open('dtrajs.pickle','rb') as file:
    dtrajs = pickle.load(file)

# %%
# Make the count matrix for various lagtimes.
# lagtimes = [1,2,5,10,20,25]
countm = []
for dtraj in dtrajs:
    c_small = []
    for lag in lagtimes:
        estimator = deeptime.markov.TransitionCountEstimator(lag, 'sliding')
        c_small.append(estimator.fit(dtraj).fetch_model())
    countm.append(c_small)

# %% [markdown]
# ## Checkpoint 2/4

# %%
# Read previous data
import pickle
with open('countm.pickle','rb') as file:
    countm = pickle.load(file)

# %%
# Write previous data
import pickle
with open('countm.pickle','wb') as file:
    pickle.dump(countm, file)

# %%
# Make MSM for each cluster/lagtime
estimator = deeptime.markov.msm.MaximumLikelihoodMSM(reversible=True, stationary_distribution_constraint=None)
msms = []
for matrix in countm:
    small = []
    for m, lag in zip(matrix, lagtimes):
        small.append(estimator.fit(m, lagtime=lag).fetch_model())
    msms.append(small)
# Out:
# Skipping state set [60] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [60] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [60] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [58] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [193] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [152] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [60] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [58] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [193] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [339] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [339] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [352] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [388] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [135] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [55] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [264] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [178] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [327] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [339] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [261] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [3] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [388] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [55] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [135] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [352] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [104] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [299] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [130] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [157] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [178] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [227] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [262] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [264] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [327] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [339] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [139] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [380] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [140] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [384] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [352] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [299] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [422] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [3] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [236] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [385] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [406] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [104] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [135] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [55] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [78] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [261] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [388] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [106] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [208] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [200] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [221] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [334] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [36] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [130] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [157] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [178] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [184] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [421] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [305] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [227] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [239] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [250] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [262] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [264] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [327] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [339] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [417] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [367] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [3] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [272] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [446] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [352] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [388] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [41] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [331] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [261] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [380] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [385] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [135] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [78] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [106] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [139] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [236] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [71] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [55] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [104] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [299] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [85] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [75] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [166] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [363] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [80] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [130] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [157] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [184] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [178] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [227] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [250] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [411] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [413] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [317] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [262] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [264] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [327] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [339] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..
# Skipping state set [367] due to error in estimation: Some row and corresponding column of the count matrix C have zero counts..

# %% [markdown]
# ## Checkpoint 3/4

# %%
# Read previous data
import pickle
with open('msms.pickle','rb') as file:
    msms = pickle.load(file)

# %%
# Write previous data
import pickle
with open('msms.pickle','wb') as file:
    pickle.dump(msms, file)

# %%
# Try and plot the many different cluster centers

# Setting up the figure/Axes objects...
fig = plt.figure(constrained_layout=True, figsize=(18,6.2))
gs = fig.add_gridspec(2, len(n_clusters))
axes = []
for idx in range(2):
    axes.append([])
    for jdx in range(len(n_clusters)):
        axes[idx].append(fig.add_subplot(gs[idx, jdx]))
axes = np.asarray(axes)
# This is a simplified way to setup but might create overlap
#fig, axes = plt.subplots(2, len(n_clusters), figsize=(18, 6.2))

# Plotting things...
for i, (n, cluster, dtraj, msm) in enumerate(zip(n_clusters, clusters, dtrajs, msms)):
    # Top row...
    deeptime.plots.plot_density(*features[:,:2].T[::-1], ax=axes[0, i]) # Note .T reverses Phi/Psi
    axes[0, i].scatter(*cluster.cluster_centers[:,:2].T, s=15, c='C1')
    axes[0, i].set_xlabel('oa1')
    axes[0, i].set_ylabel('oa2')
    axes[0, i].set_title('k = {} centers'.format(n))
    #axes[0, i].set_xticks([j for j in range(-180,181,60)])
    #axes[0, i].set_xticks([j for j in range(-180,181,60)])
    
    # Bottom row...
    deeptime.plots.plot_implied_timescales(
        deeptime.util.validation.implied_timescales(msm, n_its=9),
        ax=axes[1, i])
    axes[1, i].set_xlabel('lag time (ps)')
    axes[1, i].set_ylabel('timescale (ps)')
    axes[1, i].set_title('implied timescales')
    #axes[1, i].set_ylim(1, 2000)

#fig.tight_layout()
fig.suptitle('Different Clusters and Lag Times at a Glance')
fig.savefig('its.pdf', dpi=300)
# Out:
# /Users/darian/anaconda3/envs/msm/lib/python3.10/site-packages/deeptime/markov/tools/analysis/_api.py:256: UserWarning: truncated eigendecomposition to contain 5 components
#   warnings.warn('truncated eigendecomposition to contain %s components' % new_k, category=UserWarning)

# %%
# Blowing one of the implied timescale plot up by replotting it.
index = -1 # Looking at the last one.
plot = deeptime.plots.plot_implied_timescales(
    deeptime.util.validation.implied_timescales(msms[index], n_its=9))
plot.set_xlabel('lag time (ps)');
plot.set_ylabel('timescale (ps)');
plot.set_title(f'implied timescales for k={n_clusters[-1]} clusters');
plot.set_ylim(0,10);
plot.axvline(5, linestyle='--', color='grey');
plot.legend(lagtimes,loc='upper right');

## Choosing 10ps * 5ps = report every 50 ps
plot.figure.savefig('final_its.pdf', dpi=300)

# %%
final_lag = 5
final_cluster= clusters[index]
final_dtrajs = dtrajs[index][::5]
estimator = deeptime.markov.TransitionCountEstimator(lag, 'sliding')
final_count = estimator.fit(dtraj).fetch_model()
estimator = deeptime.markov.msm.MaximumLikelihoodMSM(reversible=True, stationary_distribution_constraint=None)
final_msm = estimator.fit(final_count, lagtime=None).fetch_model()

# %%
final_msm.transition_matrix
# Out:
# array([[0.01034823, 0.00073576, 0.00031804, ..., 0.01844174, 0.00076898,
#         0.00087341],
#        [0.00031855, 0.01187036, 0.00507614, ..., 0.00048091, 0.01423786,
#         0.01278281],
#        [0.00032703, 0.01205584, 0.0052909 , ..., 0.00040024, 0.01384225,
#         0.01249021],
#        ...,
#        [0.01028488, 0.00061947, 0.00021708, ..., 0.01847312, 0.00067506,
#         0.00071477],
#        [0.00028591, 0.01222685, 0.0050051 , ..., 0.00045004, 0.01429524,
#         0.01237683],
#        [0.00036609, 0.01237533, 0.00509139, ..., 0.0005372 , 0.01395308,
#         0.01240714]])

# %%
# Read previous data
import pickle
with open('final.pickle','rb') as file:
    [final_cluster, final_dtrajs, final_count, final_msm] = pickle.load(file)

# %%
# Write previous data
import pickle
with open('final.pickle','wb') as file:
    pickle.dump([final_cluster, final_dtrajs, final_count, final_msm], file)

# %% [markdown]
# ## Checkpoint 4

# %%
np.save('final_transition_matrix_200clusters.npy', final_msm.transition_matrix)

# %%
# Finding the index of frames closest to center
from scipy.cluster.vq import vq
cl, _ = vq(final_cluster.cluster_centers, dihedral_concat[::50])

np.save('closest_index.npy', cl)

# %%
# Loading in the coordinates
folders = [f'{num+1:02d}' for num in range(10)]
data = []
for folder in tqdm(folders):
    data.append(np.load(f'{folder}/coords.npy'))[::10]
data_concat2 = np.concatenate(data)[::50]

# %%
dihedral_concat2 = np.concatenate(dihedral)[::50]

# %%
coords = {}
for idx, j in enumerate(tqdm(cl)):
    coords[idx] = data_concat2[j]
    
import pickle
with open('coord_backmap.pickle', 'wb') as f:
    pickle.dump(coords, f)

# %%
pcoords = {}
for idx, j in enumerate(tqdm(cl)):
    pcoords[idx] = dihedral_concat2[j]
    
import pickle
with open('pcoord_backmap.pickle', 'wb') as f:
    pickle.dump(pcoords, f)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]

# %% [markdown]
# # Figuring out the start/end states.

# %%
from scipy.cluster.vq import vq
cl, _ = vq( [[-82.9094, 46.4386]], final_cluster.cluster_centers,)
cl
# Out:
# array([108], dtype=int32)

# %%
final_cluster.cluster_centers[108]
# Out:
# array([-86.38787085,  43.94791794])

# %%
for idx, cluster in enumerate(final_cluster.cluster_centers):
    if -180 < cluster[1] <-125 and 25<cluster[0] <90:
        print(cluster)
        print(idx)
# Out:
# [  56.9945094  -164.70361737]
# 119

# %%
final_msm.transition_matrix[108,119]
# Out:
# 5.397887155924061e-06

# %% [markdown]
# # Test Cells

# %%
its_models = []
for j in msms:
    its_models.append(deeptime.util.validation.implied_timescales(j))
    deeptime.plots.plot_implied_timescales(its_models[-1])

# %%
dtrajs = clusters.transform(dihedral_concat)

# %%
lagtimes = [1,2,5,10,20,25]
countm = []
for j in lagtimes:
    estimator = deeptime.markov.TransitionCountEstimator(j, 'sliding')
    countm.append(estimator.fit(dtrajs).fetch_model())
countm

# %%
estimator = deeptime.markov.msm.MaximumLikelihoodMSM(reversible=True, stationary_distribution_constraint=None)
msms = []
for matrix in countm:
    msms.append(estimator.fit(matrix).fetch_model())
#for j in msms:
#    print(j.transition_matrix)

# %%
b = deeptime.util.validation.implied_timescales(msms)
c = deeptime.plots.plot_implied_timescales(b)
c.set_ylim((0,20))

# %%
#its = pyemma.msm.its(clusters.dtrajs, lags=[1, 2, 5, 10, 20, 50], nits=4, errors='bayes')
#its = deeptime.util.validation.implied_timescales(clusters, n_its=4)

# %%
fig, axes = plt.subplots(2, 3, figsize=(12, 6))
for i, k in enumerate([20, 50, 100]):
    cluster = pyemma.coordinates.cluster_kmeans(data, k=k, max_iter=50, stride=10)
    pyemma.plots.plot_density(*data_concatenated.T, ax=axes[0, i], cbar=False, alpha=0.1)
    axes[0, i].scatter(*cluster.clustercenters.T, s=15, c='C1')
    axes[0, i].set_xlabel('$\Phi$')
    axes[0, i].set_ylabel('$\Psi$')
    axes[0, i].set_title('k = {} centers'.format(k))
    pyemma.plots.plot_implied_timescales(
        pyemma.msm.its(cluster.dtrajs, lags=[1, 2, 5, 10, 20, 50], nits=4, errors='bayes'),
        ax=axes[1, i], units='ps')
    axes[1, i].set_ylim(1, 2000)
fig.tight_layout()
